# %% [markdown]
# # Goal

# %% [markdown]
# The goal is to scrape Wildflower.org for both all it's information and to fill in the missing data in our source data

# %% [markdown]
# # Imports and Data

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests 
import re
import numpy as np

# %%
full_data = pd.read_excel("../../Data/ERA_Alabama.xlsx",sheet_name="All Plants")

# %%
full_data.head()
# Out:
#       Plant Type      Scientific Name                 Common Name  \
# 0    Tree, Shrub    Acacia farnesiana                sweet acacia
# 1  Herb (annual)  Acalypha rhomboidea    common threeseed mercury
# 2  Herb (annual)   Acalypha virginica  Virginia threeseed mercury
# 3           Tree      Acer floridanum        southern sugar maple
# 4           Tree         Acer negundo                    boxelder
#
#     Plant Family USDA Symbol                     Native Status  \
# 0       Fabaceae        ACFA  L48 (NI), HI (I), PR (N), VI (N)
# 1  Euphorbiaceae        ACRH                  L48 (N), CAN (N)
# 2  Euphorbiaceae        ACVI                           L48 (N)
# 3      Aceraceae        ACFL                           L48 (N)
# 4      Aceraceae       ACNE2                  L48 (N), CAN (N)
#
#                                  Distribution in USA             Workhorse  \
# 0             AL, AZ, CA, FL, GA, HI, LA, MS, NM, TX            Pollinator
# 1  AL, AR, CT, DC, DE, FL, GA, IA, IL, IN, KS, KY...                   NaN
# 2  AL, AR, CT, DC, DE, GA, IA, IL, IN, KS, KY, LA...                   NaN
# 3  AL, AR, FL, GA, IL, KY, LA, MO, MS, NC, OK, SC...                   NaN
# 4  AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID...  Workhorse/Pollinator
#
#   Flower Color Showy  ... Butterflies Monarchs Nesting and Structure (Bees)  \
# 0          NaN   NaN  ...         NaN      NaN                          NaN
# 1          NaN   Yes  ...         NaN      NaN                          NaN
# 2          Red   Yes  ...         NaN      NaN                          NaN
# 3       Yellow    No  ...         NaN      NaN                          NaN
# 4        White    No  ...         NaN      NaN                          Yes
#
#   Larval Host (Monarch) Larval Host (Butterfly) Larval Host (Moth)  \
# 0                   NaN                     NaN                Yes
# 1                   NaN                     NaN                Yes
# 2                   NaN                     NaN                NaN
# 3                   NaN                     NaN                NaN
# 4                   NaN                     Yes                Yes
#
#                         Larval Species (Lepidoptera) Hummingbirds Bats Wind
# 0  Amyelois transitella, Ectomyelois ceratoniae, ...          NaN  Yes  NaN
# 1                                Orthonama obstipata          NaN  NaN  NaN
# 2                                                NaN          NaN  NaN  NaN
# 3                                                NaN          NaN  NaN  Yes
# 4  Abagrotis barnesi, Abagrotis orbis, Abagrotis ...          NaN  NaN  Yes
#
# [5 rows x 51 columns]

# %%
sample_data = full_data.sample(10)

# %%
sample_data.head()
# Out:
#                       Plant Type        Scientific Name         Common Name  \
# 1104  Herb (annual or perennial)     Pluchea camphorata     camphor pluchea
# 1045               Herb (annual)  Phacelia ranunculacea  oceanblue phacelia
# 609                         Tree     Fraxinus americana           white ash
# 101             Herb (perennial)        Aruncus dioicus    bride's feathers
# 1124            Herb (perennial)     Pontederia cordata        pickerelweed
#
#          Plant Family USDA Symbol              Native Status  \
# 1104       Asteraceae       PLCA7                    L48 (N)
# 1045  Hydrophyllaceae       PHRA3                    L48 (N)
# 609          Oleaceae       FRAM2   L48 (N), HI (I), CAN (N)
# 101          Rosaceae       ARDI8  L48 (NI), AK (N), CAN (N)
# 1124   Pontederiaceae      POCO14           L48 (N), CAN (N)
#
#                                     Distribution in USA             Workhorse  \
# 1104  AL, AR, DE, FL, GA, IL, IN, KS, KY, LA, MD, MO...                   NaN
# 1045                 AL, AR, IL, IN, KY, MO, OH, TN, WV                   NaN
# 609   AL, AR, CO, CT, DC, DE, FL, GA, HI, IA, IL, IN...            Pollinator
# 101   AK, AL, AR, CA, DC, GA, IA, IL, IN, KY, MA, MD...  Workhorse/Pollinator
# 1124  AL, AR, CT, DC, DE, FL, GA, IA, IL, IN, KS, KY...  Workhorse/Pollinator
#
#      Flower Color Showy  ... Butterflies Monarchs  \
# 1104          NaN    No  ...         NaN      NaN
# 1045          NaN   NaN  ...         NaN      NaN
# 609        Yellow    No  ...         NaN      NaN
# 101         White   NaN  ...         Yes      NaN
# 1124       Purple   Yes  ...         Yes      NaN
#
#      Nesting and Structure (Bees) Larval Host (Monarch)  \
# 1104                          NaN                   NaN
# 1045                          NaN                   NaN
# 609                           NaN                   NaN
# 101                           NaN                   NaN
# 1124                          NaN                   NaN
#
#      Larval Host (Butterfly) Larval Host (Moth)  \
# 1104                     NaN                NaN
# 1045                     NaN                Yes
# 609                      Yes                Yes
# 101                      Yes                Yes
# 1124                     NaN                Yes
#
#                            Larval Species (Lepidoptera) Hummingbirds Bats Wind
# 1104                                                NaN          NaN  NaN  NaN
# 1045                               Ethmia macelhosiella          NaN  NaN  NaN
# 609   Achatia distincta, Adita chionanthi, Alsophila...          NaN  NaN  NaN
# 101   Celastrina ebenina, Celastrina nigra, Endopiza...          Yes  NaN  NaN
# 1124  Bellura densa, Bellura gortynoides, Bellura ob...          Yes  NaN  NaN
#
# [5 rows x 51 columns]

# %%
sample_condensed = sample_data[["Scientific Name","Common Name","USDA Symbol"]]
sample_condensed.to_csv("test.csv")

# %% [markdown]
# # Approach/Notes

# %% [markdown]
# Each plant is hosted on a url following a uniform structure of base + USDA symbol - https://www.wildflower.org/plants/result.php?id_plant=EUCY. The initial plan to navigate the site is to iterate through the symbol in our test data, appending each to
# the base url, and use the requests module to pull up the plant specific page. Then, we'll use beautiful soup to scrape the page.
#
# The focus is on grabbing information under the Synonyms, Plant Characteristics, Bloom Information, Growing Conditions and Benefit headers.

# %% [markdown]
# # Building out approach

# %%
BASE_URL = "https://www.wildflower.org/plants/result.php?id_plant="
HEADERS = {
    "Accept-Language": "en-US,en;q=0.9",
    "User-Agent": "Chrome/87.0.4280.141"
}

# %%
# Get the Page text for the symbol using http request module
full_url = BASE_URL + "EUCY"
response = requests.get(url = full_url, headers = HEADERS)
page = response.text 
soup = BeautifulSoup(page,features='lxml')

# %% [markdown]
# The synonyms are in a span tag with each synonym in an italicized tag. They are the only objects of this structure on the page.

# %%
soup.select('span i')
# Out:
# [<i>Euphorbia barbellata</i>,
#  <i>Euphorbia graminifolia</i>,
#  <i>Euphorbia havanensis</i>,
#  <i>Euphorbia heterophylla</i>,
#  <i>barbellata</i>,
#  <i>Euphorbia heterophylla</i>,
#  <i>cyathophora</i>,
#  <i>Euphorbia heterophylla</i>,
#  <i>graminifolia</i>,
#  <i>Poinsettia barbellata</i>,
#  <i>Poinsettia cyathophora</i>,
#  <i>Poinsettia cyathophora</i>,
#  <i>graminifolia</i>,
#  <i>Poinsettia graminifolia</i>,
#  <i>Poinsettia havanensis</i>]

# %% [markdown]
# The header (i.e. Plant Characteristics) name is in an h4 tag, the subheader (i.e. Habit) is in a strong tag. The subheaders values (i.e. Herb) are either in an anchor tag or unstructured text

# %%
soup.select('div h4')[:5]
# Out:
# [<h4>From the Image Gallery</h4>,
#  <h4>Plant Characteristics</h4>,
#  <h4>Bloom Information</h4>,
#  <h4>Distribution</h4>,
#  <h4>Growing Conditions</h4>]

# %%
all_sections = soup.find_all('div',class_="section")

# %%
list_of_relevant_sections = ["Plant Characteristics", "Bloom Information", "Growing Conditions", "Benefit"]

# %%
#Create a dictionary with key = section_name, value = BS object corresponding to that section on the page. 

named_section_dict = {}
for section in all_sections:
    section_name = section.select_one('h4').text
    if section_name in list_of_relevant_sections:
        named_section_dict[section_name] = section

# %%
named_section_dict["Benefit"]
# Out:
# <div class="section" style="float:left;width:97.3%;"><h4>Benefit</h4><strong>Use Ornamental:</strong> Accent, Garden.
# A good filler plant but can be invasive. <br/><strong>Conspicuous Flowers:</strong> yes<br/><strong>Interesting Foliage:</strong> yes<br/></div>

# %% [markdown]
# All text in a strong tag is a subheader, text between the closing strong tag and the br tag are each subheaders value. I'll use regex to grab these

# %%
#Subheaders
subheaders = [subheader.text.replace(":","") for subheader in  named_section_dict["Benefit"].select('strong')]
subheaders
# Out:
# ['Use Ornamental', 'Conspicuous Flowers', 'Interesting Foliage']

# %%
# Subheader Values
subheader_values = re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",str(named_section_dict["Benefit"]))
subheader_values
# Out:
# ['</strong> Accent, Garden.\nA good filler plant but can be invasive. <br/>',
#  '</strong> yes<br/>',
#  '</strong> yes<br/>']

# %% [markdown]
# Now we need to write some code to clean these strings and deal with scenarios when the data is in an anchor tag.

# %%
test_section = str(named_section_dict["Plant Characteristics"])

# %%
test_section
# Out:
# '<div class="section" style="float:left;width:97.3%;"><h4>Plant Characteristics</h4><strong>Duration:</strong> <a class="glossary_link" onclick="glossary(this)" title="Annual (A species that grows from seed, flowers, fruits and dies within one year\'s time.  See also, Winter Annual.                                )">Annual</a> <br/><strong>Habit:</strong> <a class="glossary_link" onclick="glossary(this)" title="Herb (A plant species lacking woody tissue when mature.                      )">Herb</a> <br/><strong>Leaf Shape:</strong> <a class="glossary_link" onclick="glossary(this)" title="Oblanceolate (Inversely lanceolate with top wider than bottom.                      )">Oblanceolate</a> <br/><strong>Leaf Pubescence:</strong> <a class="glossary_link" onclick="glossary(this)" title="Glabrous (Smooth; hairless.)">Glabrous</a> <br/><strong>Leaf Texture:</strong> Smooth <br/><strong>Leaf:</strong> The upper or bracteal leaves usually red toward the base. <br/><strong>Flower:</strong> Flowers 3-5 mm <br/><strong>Fruit:</strong> 4.5-5 mm <br/><strong>Size Class:</strong> 1-3 ft. <br/></div>'

# %%
# Approach to catch text between anchor tags.

string = re.sub("<a.*?>","",test_section) #Remove all characters within starting a tag
string = re.sub("</a>","",string) #Remove all characters within closing a tag

# %%
string
# Out:
# '<div class="section" style="float:left;width:97.3%;"><h4>Plant Characteristics</h4><strong>Duration:</strong> Annual <br/><strong>Habit:</strong> Herb <br/><strong>Leaf Shape:</strong> Oblanceolate <br/><strong>Leaf Pubescence:</strong> Glabrous <br/><strong>Leaf Texture:</strong> Smooth <br/><strong>Leaf:</strong> The upper or bracteal leaves usually red toward the base. <br/><strong>Flower:</strong> Flowers 3-5 mm <br/><strong>Fruit:</strong> 4.5-5 mm <br/><strong>Size Class:</strong> 1-3 ft. <br/></div>'

# %%
def clean_subheader_values(string):
    string = str(string).replace("</strong>","").replace("<br/>","")
    new_string = ",".join(string.split(" , ")) #Remove spacing with csv's
    return new_string

string = re.sub("<a.*?>","",str(test_section))
string = re.sub("</a>","",string)
subheader_values = [clean_subheader_values(val) for val in re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",string)]

# %%
subheaders = [subheader.text.replace(":","") for subheader in  named_section_dict["Plant Characteristics"].select('strong')]


for head,val in list(zip(subheaders,subheader_values)):
    print(head,":",val)
# Out:
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.

# %% [markdown]
# Repeat process for each section

# %%
lst_of_section_subheaders = [[subheader.text.replace(":","") for subheader in  named_section_dict[section].select('strong')] for section in named_section_dict.keys()]

list_of_section_values = [
    [clean_subheader_values(val) for val in re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",re.sub("</a>","",re.sub("<a.*?>","",str(named_section_dict[section]))))] for section in named_section_dict.keys()]

# %%
for section_subheaders_lst, section_values_lst in list(zip(lst_of_section_subheaders,list_of_section_values)):
    for head,val in list(zip(section_subheaders_lst,section_values_lst)):
        print(head,":",val)
# Out:
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes

# %% [markdown]
# Run solution on sample data

# %%
list_of_page_soups = []

for symbol in sample_condensed["USDA Symbol"].to_list():
        
    full_url = BASE_URL + symbol
    response = requests.get(url = full_url, headers = HEADERS)
    list_of_page_soups.append(BeautifulSoup(response.text,features='lxml'))

# %%
for page_soup in list_of_page_soups:
    print(page_soup.select('div h4')[:5])
# Out:
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>National Wetland Indicator Status</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>National Wetland Indicator Status</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>From the National Organizations Directory </h4>]
# [<h4>From the Image Gallery</h4>, <h4>Plant Characteristics</h4>, <h4>Bloom Information</h4>, <h4>Distribution</h4>, <h4>Growing Conditions</h4>]

# %%
# list_of_relevant_sections = ["Plant Characteristics", "Bloom Information", "Growing Conditions", "Benefit","Value to Beneficial Insects"] Insects section rare and does not fit regex pattern
list_of_relevant_sections = ["Plant Characteristics", "Bloom Information", "Growing Conditions", "Benefit","Propagation"]

for page_soup in list_of_page_soups:

    all_sections = soup.find_all('div',class_="section")

    named_section_dict = {}
    for section in all_sections:
        section_name = section.select_one('h4').text
        if section_name in list_of_relevant_sections:
            named_section_dict[section_name] = section
    
    lst_of_section_subheaders = [[subheader.text.replace(":","") for subheader in  named_section_dict[section].select('strong')] for section in named_section_dict.keys()]

    list_of_section_values = [
        [clean_subheader_values(val) for val in re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",re.sub("</a>","",re.sub("<a.*?>","",str(named_section_dict[section]))))] for section in named_section_dict.keys()]


    for section_subheaders_lst, section_values_lst in list(zip(lst_of_section_subheaders,list_of_section_values)):
        for head,val in list(zip(section_subheaders_lst,section_values_lst)):
            print(head,":",val)
# Out:
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes
# Duration :  Annual
# Habit :  Herb
# Leaf Shape :  Oblanceolate
# Leaf Pubescence :  Glabrous
# Leaf Texture :  Smooth
# Leaf :  The upper or bracteal leaves usually red toward the base.
# Flower :  Flowers 3-5 mm
# Fruit :  4.5-5 mm
# Size Class :  1-3 ft.
# Bloom Color :  Yellow,Green
# Bloom Time :  May,Jun,Jul,Aug,Sep,Oct,Nov
# Water Use :  Medium
# Light Requirement :  Sun
# Soil Moisture :  Moist
# Soil Description :  Sandy, Sandy Loam, Medium Loam, Clay Loam
# Use Ornamental :  Accent, Garden.
# A good filler plant but can be invasive.
# Conspicuous Flowers :  yes
# Interesting Foliage :  yes

# %% [markdown]
# Now we want to find a way to store a single plants data

# %%
all_sections = soup.find_all('div',class_="section")

named_section_dict = {}
for section in all_sections:
    section_name = section.select_one('h4').text
    if section_name in list_of_relevant_sections:
        named_section_dict[section_name] = section


lst_of_section_subheaders = []

for section in named_section_dict.keys():
    for subheader in  named_section_dict[section].select('strong'):
        lst_of_section_subheaders.append(subheader.text.replace(":",""))

list_of_section_values = []
for section in named_section_dict.keys():
    full_section_cleaned = re.sub("</a>","",re.sub("<a.*?>","",str(named_section_dict[section]))).replace("\n"," ")

    for val in re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",full_section_cleaned):
        list_of_section_values.append(clean_subheader_values(val))

plant_dict = {}
for head, val in list(zip(lst_of_section_subheaders,list_of_section_values)):
    plant_dict[head] = val

print(plant_dict)
# Out:
# {'Duration': ' Annual ', 'Habit': ' Herb ', 'Leaf Shape': ' Oblanceolate ', 'Leaf Pubescence': ' Glabrous ', 'Leaf Texture': ' Smooth ', 'Leaf': ' The upper or bracteal leaves usually red toward the base. ', 'Flower': ' Flowers 3-5 mm ', 'Fruit': ' 4.5-5 mm ', 'Size Class': ' 1-3 ft. ', 'Bloom Color': ' Yellow,Green ', 'Bloom Time': ' May,Jun,Jul,Aug,Sep,Oct,Nov ', 'Water Use': ' Medium ', 'Light Requirement': ' Sun ', 'Soil Moisture': ' Moist ', 'Soil Description': ' Sandy, Sandy Loam, Medium Loam, Clay Loam ', 'Use Ornamental': ' Accent, Garden. A good filler plant but can be invasive. ', 'Conspicuous Flowers': ' yes', 'Interesting Foliage': ' yes'}

# %% [markdown]
# Now grab and join data for all plants in sample

# %%
for symbol in sample_condensed["USDA Symbol"]:
    print(symbol)
# Out:
# PLCA7
# PHRA3
# FRAM2
# ARDI8
# POCO14
# ASHU3
# HETU
# ACNI5
# SIRO4
# CATO4

# %%
labeled_plant_dicts = {}
list_of_unique_subheaders = []

for symbol in sample_condensed["USDA Symbol"]:

    full_url = BASE_URL + symbol
    response = requests.get(url = full_url, headers = HEADERS)
    soup = BeautifulSoup(response.text,features='lxml')

    all_sections = soup.find_all('div',class_="section")

    named_section_dict = {}
    for section in all_sections:
        section_name = section.select_one('h4').text
        if section_name in list_of_relevant_sections:
            named_section_dict[section_name] = section


    lst_of_section_subheaders = []
    for section in named_section_dict.keys():
        for subheader in  named_section_dict[section].select('strong'):
            subheader = subheader.text.replace(":","")
            if subheader not in list_of_unique_subheaders:
                list_of_unique_subheaders.append(subheader)
            lst_of_section_subheaders.append(subheader)

    list_of_section_values = []
    for section in named_section_dict.keys():
        full_section_cleaned = re.sub("</a>","",re.sub("<a.*?>","",str(named_section_dict[section]))).replace("\n"," ")

        for val in re.findall("<\/strong>[\w\s\\.\-\,]+<br\/>",full_section_cleaned):
            list_of_section_values.append(clean_subheader_values(val))

    plant_dict = {}
    for head, val in list(zip(lst_of_section_subheaders,list_of_section_values)):
        plant_dict[head] = val
    
    labeled_plant_dicts.update({symbol:plant_dict})

# %%
labeled_plant_dicts
# Out:
# {'PLCA7': {'Duration': ' Annual ',
#   'Habit': ' Herb ',
#   'Size Class': ' 3-6 ft. ',
#   'Bloom Color': ' Pink,Purple ',
#   'Bloom Time': ' Aug,Sep,Oct ',
#   'Bloom Notes': ' Blooms year-round in South. '},
#  'PHRA3': {'Duration': ' Annual ',
#   'Habit': ' Herb ',
#   'Fruit Type': ' Capsule ',
#   'Size Notes': ' Up to about 10 inches tall. ',
#   'Bloom Color': ' White,Violet ',
#   'Bloom Time': ' Mar,Apr,May ',
#   'Bloom Notes': ' Pale violet to white. '},
#  'FRAM2': {'Duration': ' Perennial ',
#   'Habit': ' Tree ',
#   'Leaf Retention': ' Deciduous ',
#   'Breeding System': ' Flowers Unisexual,Monoecious ',
#   'Fruit Type': ' Samara ',
#   'Size Notes': ' Up to about 120 feet tall. ',
#   'Leaf': ' Green ',
#   'Autumn Foliage': ' yes',
#   'Fruit': ' Green ',
#   'Bloom Color': ' Yellow,Purple ',
#   'Bloom Time': ' Apr,May ',
#   'Water Use': ' High ',
#   'Light Requirement': ' Sun,Part Shade,Shade ',
#   'Soil Moisture': ' Dry,Moist ',
#   'Soil pH': ' Medium ',
#   'CaCO3 Tolerance': ' yes',
#   'Cold Tolerant': ' Deep, mesic soils. Sandy, Sandy Loam, Medium Loam, Clay Loam, Clay. ',
#   'Soil Description': ' Shade tree, Fall conspicuous ',
#   'Conditions Comments': ' Winged seeds attract song and game birds. Cover, Nesting site, Seeds-granivorous birds, Browse. ',
#   'Use Ornamental': ' Birds,Butterflies ',
#   'Use Wildlife': ' Seeds ',
#   'Use Other': ' Seeds may be sown outdoors after collection or stored and stratified then sown in spring. ',
#   'Attracts': ' Stratify in moist sand or perlite for 30-60 days at 41 degrees. Some references suggest preceding this treatment with an equal period of warm stratification. ',
#   'Larval Host': ' yes'},
#  'ARDI8': {'Duration': ' Perennial ',
#   'Habit': ' Herb ',
#   'Root Type': ' Tap ',
#   'Leaf Margin': ' Dentate ',
#   'Breeding System': ' Flowers Unisexual,Dioecious ',
#   'Fruit Type': ' Legume ',
#   'Size Notes': ' Up to about 6 feet tall. ',
#   'Flower': ' Flower clusters 6 to 24 inches long. ',
#   'Bloom Color': ' White ',
#   'Bloom Time': ' May,Jun,Jul,Aug ',
#   'Bloom Notes': ' Male plants have showier flowers. ',
#   'Water Use': ' Medium,High ',
#   'Light Requirement': ' Sun,Part Shade,Shade ',
#   'Soil Moisture': ' Moist,Wet ',
#   'Soil pH': ' Average to acid, mesic to moist soil. ',
#   'Soil Description': ' Tolerates seasonal flooding. Needs a lot of space. ',
#   'Conditions Comments': ' Good for large-scale displays of white blooms in spring and summer, such as massed in a drift down a slope. ',
#   'Use Ornamental': ' yes',
#   'Conspicuous Flowers': ' Butterflies ',
#   'Attracts': ' Dusky Azure ',
#   'Larval Host': ' Root Division,Seeds ',
#   'Propagation Material': ' Propagate by division or seed. ',
#   'Description': ' Ripens one month after blooming, female plants only. ',
#   'Seed Collection': ' yes'},
#  'POCO14': {'Duration': ' Perennial ',
#   'Habit': ' Herb ',
#   'Size Notes': ' Green ',
#   'Leaf': ' 1-3 ft. ',
#   'Size Class': ' White,Blue,Purple ',
#   'Bloom Color': ' Jun,Jul,Aug,Sep ',
#   'Bloom Time': ' High ',
#   'Water Use': ' Sun,Part Shade ',
#   'Light Requirement': ' Moist,Wet ',
#   'Soil Moisture': ' Medium ',
#   'CaCO3 Tolerance': ' Sandy, Sandy Loam, Medium Loam, Clay, Clay Loam, Mud ',
#   'Soil Description': ' A true pond plant, pickerelweed is easy to grow so long as it does not dry out. The hyacinth-like flowers continue to bloom through the summer. Regularly divide the plant to keep it from growing too large. Pickerelweed provides nectar for bees and butterflies. Good for wetland gardens and habitat. ',
#   'Conditions Comments': ' Water garden, Bog or pond area ',
#   'Use Ornamental': ' Seeds eaten by waterfowl. Attracts dragonflies. ',
#   'Use Wildlife': ' yes',
#   'Use Food': ' Birds ',
#   'Conspicuous Flowers': ' Minimal ',
#   'Attracts': ' yes'},
#  'ASHU3': {'Duration': ' Perennial ',
#   'Habit': ' Herb ',
#   'Root Type': ' Tap ',
#   'Leaf Retention': ' Evergreen ',
#   'Leaf Arrangement': ' Opposite ',
#   'Leaf Complexity': ' Simple ',
#   'Leaf Venation': ' Pinnate ',
#   'Breeding System': ' Flowers Bisexual ',
#   'Inflorescence': ' Umbel ',
#   'Fruit Type': ' Follicle ',
#   'Size Notes': ' Stems sprawling or ascending, up to about 18 inches long. ',
#   'Leaf': ' Clasping. Stem and veins in the leaves are a pale purple. Leaf arrangement is opposite and attachment is sessile. ',
#   'Flower': ' White,Pink ',
#   'Fruit': ' Mar,Apr,May,Jun ',
#   'Bloom Color': ' Medium ',
#   'Bloom Time': ' Sun ',
#   'Water Use': ' Dry ',
#   'Light Requirement': ' Dry, sandy soils. ',
#   'Soil Moisture': ' Full sun to nearly full sun. This flower tolerates very hot, dry conditions. ',
#   'Soil Description': ' yes',
#   'Conditions Comments': ' Butterflies ',
#   'Warning': ' Root cuttings can be taken in fall or early spring. Seeds may be sown outside in late fall or the following spring. Germination of spring-planted seeds is enhanced by moist stratification. ',
#   'Conspicuous Flowers': ' Not Available ',
#   'Attracts': ' Stratify 3 months at 40 degrees. ',
#   'Description': ' yes'},
#  'HETU': {'Duration': ' Perennial ',
#   'Habit': ' Herb ',
#   'Leaf': ' Yellow-Green ',
#   'Size Class': ' 3-6 ft. ',
#   'Bloom Color': ' Red,Pink,Yellow ',
#   'Bloom Time': ' Aug,Sep,Oct ',
#   'Water Use': ' Low ',
#   'Light Requirement': ' Sun ',
#   'Soil Moisture': ' Dry,Moist ',
#   'CaCO3 Tolerance': ' Medium ',
#   'Soil Description': ' Moist to drying soil. ',
#   'Conditions Comments': ' Jerusalem artichoke is aggressive and escapes from garden settings. ',
#   'Use Wildlife': ' Foliage and tubers are eaten by livestock and deer. Seed heads attract birds. The plant provides cover for wildlife. ',
#   'Conspicuous Flowers': ' yes'},
#  'ACNI5': {'Duration': ' Perennial ',
#   'Habit': ' Tree ',
#   'Leaf Retention': ' Deciduous ',
#   'Leaf Arrangement': ' Opposite ',
#   'Leaf Complexity': ' Simple ',
#   'Leaf Venation': ' Palmate ',
#   'Leaf Pubescence': ' Tomentose ',
#   'Leaf Margin': ' Lobed ',
#   'Size Notes': ' Up to about 100 feet tall. ',
#   'Leaf': ' Green ',
#   'Autumn Foliage': ' yes',
#   'Flower': ' Flowers small ',
#   'Fruit': ' Green, Brown Two-winged horseshoe-shaped samaras about 1in long, appearing in clusters. ',
#   'Bloom Color': ' Yellow,Green ',
#   'Bloom Time': ' Apr,May ',
#   'Bloom Notes': ' Flowers appear with the leaves. ',
#   'Water Use': ' Medium ',
#   'Light Requirement': ' Part Shade,Shade ',
#   'Soil Moisture': ' Moist ',
#   'CaCO3 Tolerance': ' Medium ',
#   'Soil Description': ' Dry to moist, often calcareous soils. ',
#   'Description': ' Propagation is possible by seed. Not considered easy to root from cuttings. ',
#   'Seed Collection': ' The winged fruit of maples is called a samara. Seed is usually not extracted from the samara. ',
#   'Seed Treatment': ' yes'},
#  'SIRO4': {'Duration': ' Perennial ',
#   'Habit': ' Herb ',
#   'Leaf Shape': ' Oblanceolate,Peltate ',
#   'Leaf Apex': ' Acuminate ',
#   'Leaf Base': ' Cuneate,Peltate ',
#   'Inflorescence': ' Cyme ',
#   'Fruit Type': ' Capsule ',
#   'Bloom Color': ' Red ',
#   'Bloom Time': ' May,Jun,Jul,Aug '},
#  'CATO4': {'Duration': ' Perennial ',
#   'Habit': ' Fibrous ',
#   'Root Type': ' Alternate ',
#   'Leaf Arrangement': ' Simple ',
#   'Leaf Complexity': ' Linear ',
#   'Leaf Shape': ' Parallel ',
#   'Leaf Venation': ' Glabrous ',
#   'Leaf Pubescence': ' Entire ',
#   'Leaf Margin': ' Flowers Unisexual,Monoecious ',
#   'Breeding System': ' Spike ',
#   'Inflorescence': ' Achene ',
#   'Fruit Type': ' Up to about 30 inches tall. ',
#   'Size Notes': ' Green ',
#   'Leaf': ' White,Yellow,Green,Brown ',
#   'Bloom Color': ' Jun ',
#   'Bloom Time': ' Medium ',
#   'Bloom Notes': ' Part Shade ',
#   'Water Use': ' Low '}}

# %%
list_of_unique_subheaders
# Out:
# ['Duration',
#  'Habit',
#  'Size Class',
#  'Bloom Color',
#  'Bloom Time',
#  'Bloom Notes',
#  'Fruit Type',
#  'Size Notes',
#  'Leaf Retention',
#  'Breeding System',
#  'Leaf',
#  'Autumn Foliage',
#  'Fruit',
#  'Water Use',
#  'Light Requirement',
#  'Soil Moisture',
#  'Soil pH',
#  'CaCO3 Tolerance',
#  'Cold Tolerant',
#  'Soil Description',
#  'Conditions Comments',
#  'Use Ornamental',
#  'Use Wildlife',
#  'Use Other',
#  'Attracts',
#  'Larval Host',
#  'Propagation Material',
#  'Description',
#  'Seed Treatment',
#  'Commercially Avail',
#  'Root Type',
#  'Leaf Margin',
#  'Flower',
#  'Conspicuous Flowers',
#  'Seed Collection',
#  'Use Food',
#  'Deer Resistant',
#  'Leaf Arrangement',
#  'Leaf Complexity',
#  'Leaf Venation',
#  'Inflorescence',
#  'Warning',
#  'Leaf Pubescence',
#  'Leaf Shape',
#  'Leaf Apex',
#  'Leaf Base']

# %%
for symbol,plant_dict in labeled_plant_dicts.items():
    for subheader in list_of_unique_subheaders:
        if subheader not in plant_dict.keys():
            plant_dict.update({subheader:np.nan})

# %%
for val in labeled_plant_dicts.values():
    print(len(val))
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46

# %%
index = labeled_plant_dicts.keys()
print(index)
# Out:
# dict_keys(['PONO3', 'HEHI', 'HESU3', 'PYAL', 'SEPO2', 'PRTR', 'ROVI2', 'DAAL2', 'LOUN', 'CAFL3'])

# %%
from collections import defaultdict

# %%
dd = defaultdict(list)

for d in labeled_plant_dicts.values(): # you can list as many input dicts as you want here
    for key, value in d.items():
        dd[key].append(value)

# %%
pd.DataFrame(dd,index=index)
# Out:
#           Duration            Habit  \
# PONO3      Annual             Herb
# HEHI       Annual             Herb
# HESU3      Annual             Herb
# PYAL    Perennial             Herb
# SEPO2   Perennial             Vine
# PRTR    Perennial             Herb
# ROVI2   Perennial            Shrub
# DAAL2   Perennial    Herb,Subshrub
# LOUN       Annual             Herb
# CAFL3   Perennial           Oblong
#
#                                               Size Notes  \
# PONO3                          Up to about 3 feet tall.
# HEHI                                                 NaN
# HESU3                                                NaN
# PYAL                                                 yes
# SEPO2   Stems trailing, much-branched, sometimes form...
# PRTR                                                 NaN
# ROVI2                                                NaN
# DAAL2                                             White
# LOUN                                                 NaN
# CAFL3                                                NaN
#
#                 Bloom Color  \
# PONO3               Yellow
# HEHI           Blue,Purple
# HESU3               Yellow
# PYAL           Jul,Aug,Sep
# SEPO2          Pink,Purple
# PRTR          White,Yellow
# ROVI2   Pink,Yellow,Purple
# DAAL2                   NaN
# LOUN            White,Pink
# CAFL3              May,Jun
#
#                                               Bloom Time  \
# PONO3                                   Jun,Jul,Aug,Sep
# HEHI                                        May,Jun,Jul
# HESU3                               Jul,Aug,Sep,Oct,Nov
# PYAL    Dense clusters of small white flowers with pu...
# SEPO2   Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec
# PRTR                                        Aug,Sep,Oct
# ROVI2                                       Jun,Jul,Aug
# DAAL2                                                NaN
# LOUN                                        Jun,Jul,Aug
# CAFL3                                                NaN
#
#        The Xerces Society for Invertebrate Conservation  Root Type  \
# PONO3                                               NaN        NaN
# HEHI                                                NaN        NaN
# HESU3                                               NaN        NaN
# PYAL                                                NaN   Fibrous
# SEPO2                                               NaN        NaN
# PRTR                                                NaN        NaN
# ROVI2                                               NaN        NaN
# DAAL2                                               NaN        NaN
# LOUN                                                NaN        NaN
# CAFL3                                               NaN        NaN
#
#       Leaf Retention Leaf Arrangement Leaf Complexity  ... Leaf Pubescence  \
# PONO3            NaN              NaN             NaN  ...             NaN
# HEHI             NaN              NaN             NaN  ...             NaN
# HESU3            NaN              NaN             NaN  ...             NaN
# PYAL      Deciduous         Opposite          Simple   ...             NaN
# SEPO2            NaN        Opposite              NaN  ...       Glabrous
# PRTR             NaN              NaN             NaN  ...             NaN
# ROVI2            NaN              NaN             NaN  ...             NaN
# DAAL2            NaN       Alternate              NaN  ...             NaN
# LOUN             NaN              NaN             NaN  ...             NaN
# CAFL3            NaN              NaN             NaN  ...          Spike
#
#        Inflorescence                                   Fruit  \
# PONO3            NaN                                     NaN
# HEHI             NaN                                     NaN
# HESU3            NaN                                     NaN
# PYAL             NaN                                     NaN
# SEPO2      Axillary    Seeds are black, smooth and lustrous
# PRTR             NaN                                     NaN
# ROVI2            NaN                                    Red
# DAAL2            NaN                                     NaN
# LOUN             NaN                                     NaN
# CAFL3   White,Green                                      NaN
#
#       Conspicuous Flowers                       Leaf CaCO3 Tolerance  \
# PONO3                 NaN                        NaN             NaN
# HEHI                  NaN                        NaN             NaN
# HESU3                 NaN                        NaN             NaN
# PYAL                  NaN                        NaN             NaN
# SEPO2                 NaN                        NaN             NaN
# PRTR                  yes                        NaN             NaN
# ROVI2                 NaN                     Green             Low
# DAAL2                 NaN   Jun,Jul,Aug,Sep,Oct,Nov              NaN
# LOUN                  NaN                        NaN             NaN
# CAFL3                 NaN                        NaN             NaN
#
#                               Use Food Warning Flower  Leaf Shape
# PONO3                              NaN     NaN    NaN         NaN
# HEHI                               NaN     NaN    NaN         NaN
# HESU3                              NaN     NaN    NaN         NaN
# PYAL                               NaN     NaN    NaN         NaN
# SEPO2                              NaN     NaN    NaN         NaN
# PRTR                               NaN     NaN    NaN         NaN
# ROVI2   Plant has thorns or prickles.      yes    NaN         NaN
# DAAL2                              NaN     NaN    NaN         NaN
# LOUN                               NaN     NaN    NaN         NaN
# CAFL3                              NaN     NaN    NaN   Glabrous
#
# [10 rows x 32 columns]

# %% [markdown]
# Need to write code to handle if the plant isn't in the db

# %%
full_url = BASE_URL + "UUUU"
response = requests.get(url = full_url, headers = HEADERS)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # Overview of data

# %%
with open("WildflowerColumns.txt","w") as f:
    for col in pd.read_csv("WildflowerFull.csv").columns:
        f.write(col + "\n")

# %% [markdown]
# # Join with source data - Test

# %%
wildflower = pd.read_csv("WildflowerFull.csv",index_col=0)

# %%
full_data.columns
# Out:
# Index(['Plant Type', 'Scientific Name', 'Common Name', 'Plant Family',
#        'USDA Symbol', 'Native Status', 'Distribution in USA', 'Workhorse',
#        'Flower Color', 'Showy', 'Flowering Months', 'Height (feet)',
#        'Lifespan', 'Growth Form', 'Shape and Orientation', 'Fall Conspicuous',
#        'Leaf Retention', 'Sun Exposure', 'Soil Moisture', 'Moisture Use',
#        'Soil Texture', 'Salt Tolerance', 'pH (Range)', 'Fertility Requirement',
#        'Growth Rate', 'Active Growth Period', 'Hedge Tolerance',
#        'Resprout Ability', 'Drought Tolerance', 'Fire Tolerance',
#        'Palatability (Browsing/Grazing)', 'Propagation',
#        'Commercially Available', 'Pollinator Value', 'Benefits To Pollinators',
#        'Pollinators', 'Native Bees (except Bombus)', 'Bombus', 'Honey Bees',
#        'Beetles, Wasps, Flies', 'Moths', 'Butterflies', 'Monarchs',
#        'Nesting and Structure (Bees)', 'Larval Host (Monarch)',
#        'Larval Host (Butterfly)', 'Larval Host (Moth)',
#        'Larval Species (Lepidoptera)', 'Hummingbirds', 'Bats', 'Wind'],
#       dtype='object')

# %%
wildflower.columns
# Out:
# Index(['Duration', 'Habit', 'Root Type', 'Leaf Arrangement', 'Leaf Shape',
#        'Leaf Apex', 'Fruit Type', 'Size Notes', 'Bloom Color', 'Bloom Time',
#        'Bloom Notes', 'Light Requirement', 'Soil Moisture', 'Leaf',
#        'Water Use', 'CaCO3 Tolerance', 'Conspicuous Flowers', 'Leaf Retention',
#        'Leaf Complexity', 'Leaf Margin', 'Autumn Foliage', 'Flower', 'Fruit',
#        'Cold Tolerant', 'Soil Description', 'Conditions Comments',
#        'Propagation Material', 'Description', 'Seed Collection',
#        'Seed Treatment', 'Commercially Avail', 'Leaf Venation',
#        'Leaf Pubescence', 'Leaf Base', 'Breeding System', 'Inflorescence',
#        'Drought Tolerance', 'Use Ornamental', 'Use Wildlife', 'Use Food',
#        'Warning', 'Attracts', 'Leaf Texture', 'Soil pH', 'Heat Tolerant',
#        'Use Other', 'Interesting Foliage', 'Larval Host', 'Deer Resistant',
#        'Use Medicinal', 'Fragrant Foliage', 'Fragrant Flowers', 'Maintenance',
#        'Nectar Source', 'Aquatic', 'Poisonous', 'Size Class', ' toxic ',
#        'aggressive'],
#       dtype='object')

# %% [markdown]
# flowering_months = bloom_time,

# %%
wildflower.rename(columns={'Bloom Time':'Flowering Months','Bloom Color':'Flower Color'},inplace=True)

# %%
columns_to_update = list(set(wildflower.columns).intersection(full_data.columns))
print(columns_to_update)
# Out:
# ['Soil Moisture', 'Drought Tolerance', 'Flower Color', 'Leaf Retention', 'Flowering Months']

# %%
wildflower = wildflower[columns_to_update]

# %%
temp = full_data[["USDA Symbol"] + columns_to_update][:100].set_index("USDA Symbol")

# %%
for symbol in wildflower.index:
    if symbol not in temp.index:
        wildflower.drop(symbol,inplace=True)

# %%
temp
# Out:
#                Soil Moisture Drought Tolerance Flower Color Leaf Retention  \
# USDA Symbol
# ACFA                     Dry               NaN          NaN            NaN
# ACRH              Moist, Dry               NaN          NaN            NaN
# ACVI              Moist, Dry            Medium          Red      Deciduous
# ACFL              Wet, Moist               Low       Yellow      Deciduous
# ACNE2             Wet, Moist              High        White      Deciduous
# ...                      ...               ...          ...            ...
# ARPL4        Wet, Moist, Dry               NaN          NaN            NaN
# ARRE6                    NaN               NaN          NaN            NaN
# ARPR2                    NaN               NaN          NaN            NaN
# ARAR7             Wet, Moist               Low        White      Deciduous
# ARME6             Moist, Dry               NaN        White            NaN
#
#             Flowering Months
# USDA Symbol
# ACFA                     NaN
# ACRH                     NaN
# ACVI                 Jun–Jul
# ACFL                 Apr–May
# ACNE2                Mar–Apr
# ...                      ...
# ARPL4                    NaN
# ARRE6                    NaN
# ARPR2                    NaN
# ARAR7                Mar–May
# ARME6                May–Jun
#
# [100 rows x 5 columns]

# %%
wildflower
# Out:
#       Soil Moisture Drought Tolerance          Flower Color Leaf Retention  \
# ACRH     Dry,Moist                NaN                Green             NaN
# ACVI            NaN               NaN     Red,Yellow,Green             NaN
# ACFL           Dry                NaN         Yellow,Green      Deciduous
# ACNE2        Moist              High    Yellow,Green,Brown      Deciduous
# ACNI5        Moist                NaN         Yellow,Green      Deciduous
# ...             ...               ...                   ...            ...
# ARPL4        Moist                NaN          White,Green             NaN
# ARRE6           NaN               NaN          White,Green             NaN
# ARPR2           NaN               NaN           White,Pink             NaN
# ARAR7        Moist                NaN           White,Pink      Deciduous
# ARME6        Moist                NaN           White,Pink      Deciduous
#
#                 Flowering Months
# ACRH    Jun,Jul,Aug,Sep,Oct,Nov
# ACVI    Jun,Jul,Aug,Sep,Oct,Nov
# ACFL                        Apr
# ACNE2                   Mar,Apr
# ACNI5                   Apr,May
# ...                          ...
# ARPL4           May,Jun,Jul,Aug
# ARRE6       May,Jun,Jul,Aug,Sep
# ARPR2                        NaN
# ARAR7           Feb,Mar,Apr,May
# ARME6           Mar,Apr,May,Jun
#
# [97 rows x 5 columns]

# %%
dict_wildflower = wildflower.to_dict()
dict_temp = temp.to_dict()

# %%
for col in columns_to_update:
    for symbol in temp.index:
        if dict_temp[col][symbol] is np.nan:
            if (symbol in wildflower.index) and (dict_wildflower[col][symbol] is not np.nan):
                print("Replaced")
                dict_temp[col][symbol] = dict_wildflower[col][symbol]
# Out:
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced
# Replaced

# %%
temp = pd.DataFrame(dict_temp)

# %%
temp.isna().sum()
# Out:
# Soil Moisture        11
# Drought Tolerance    52
# Flower Color          1
# Leaf Retention       49
# Flowering Months      2
# dtype: int64

# %% [markdown]
# # Join - Implemenation

# %%
wildflower = pd.read_csv("WildflowerFullOriginal.csv",index_col=0)
era = full_data.set_index("USDA Symbol")

# %%
wildflower.rename(columns={'Bloom Time':'Flowering Months','Bloom Color':'Flower Color'},inplace=True)
columns_to_update = list(set(wildflower.columns).intersection(era.columns))

# %%
wildflower = wildflower[columns_to_update]
era_condensed = era[columns_to_update]

# %%
era_condensed.isna().sum()
# Out:
# Soil Moisture        293
# Drought Tolerance    974
# Flower Color         749
# Leaf Retention       972
# Flowering Months     697
# dtype: int64

# %%
for symbol in wildflower.index:
    if symbol not in era_condensed.index:
        wildflower.drop(symbol,inplace=True)

# %%
dict_wildflower = wildflower.to_dict()
dict_era_condensed = era_condensed.to_dict()

# %%
counter = 0
for col in columns_to_update:
    for symbol in era_condensed.index:
        if dict_era_condensed[col][symbol] is np.nan:
            if (symbol in wildflower.index) and (dict_wildflower[col][symbol] is not np.nan):
                counter += 1
                dict_era_condensed[col][symbol] = dict_wildflower[col][symbol]
print(counter)
# Out:
# 1558

# %%
df = pd.DataFrame(dict_era_condensed)
df.isna().sum()
# Out:
# Soil Moisture        212
# Drought Tolerance    932
# Flower Color          29
# Leaf Retention       861
# Flowering Months      93
# dtype: int64
